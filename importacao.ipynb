# %%
pip install mysql-connector-python
# Out:
# ...
#   Obtaining dependency information for mysql-connector-python from https://files.pythonhosted.org/packages/96/db/50f7397d0c8b013b87ad402f60892335dab6680a373c6aa583fa20c7b7a8/mysql_connector_python-8.2.0-cp312-cp312-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/527.0 kB ? eta -:--:--
#       --------------------------------------- 10.2/527.0 kB ? eta -:--:--
#      ---- -------------------------------- 61.4/527.0 kB 825.8 kB/s eta 0:00:01
#      ----------- -------------------------- 153.6/527.0 kB 1.1 MB/s eta 0:00:01
#      ------------------------ ------------- 337.9/527.0 kB 1.9 MB/s eta 0:00:01
#      ---------------------------------- --- 481.3/527.0 kB 2.2 MB/s eta 0:00:01
#      -------------------------------------- 527.0/527.0 kB 2.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/14.2 MB ? eta -:--:--
#    ---------------------------------------- 0.2/14.2 MB 5.3 MB/s eta 0:00:03
# ...

# %%
mysqlimport -u SEU_USUARIO -p SUA_SENHA --local --fields-terminated-by=',' --lines-terminated-by='\n' NOME_DO_BANCO_DE_DADOS NOME_DA_TABELA ARQUIVO.csv

# %%
mysqlimport -u root -p mysql --local --fields-terminated-by=',' --lines-terminated-by='\n' embraer teamusa dataFrameTimes.csv
# Out:
#   Cell In[3], line 1
#     mysqlimport -u root -p mysql --local --fields-terminated-by=',' --lines-terminated-by='\n' embraer teamusa dataFrameTimes.csv
#                    ^
# SyntaxError: invalid syntax

# %%
C:\Users\user\OneDrive\Documents\GitHub\curso-embraer\dataFrameTimes.csv
